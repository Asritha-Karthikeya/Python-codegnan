# %% [markdown]
# #### Name Pattren Printing

# %%
n = 5
for i in range(n):
    for j in range(n):
        if j==0 or j==n-1 or i==0 or i==n//2:
            print('*',end=' ')
        else:
            print(' ',end=' ')
    print()
# Out:
# * * * * *
# *       *
# * * * * *
# *       *
# *       *

# %%
n = 5
for i in range(n):
    for j in range(n):
        if i==0 or (j==n-1 and i>n//2) or i==n//2 or i==n-1 or (j==0 and i<=n//2):
            print('*',end=' ')
        else:
            print(' ',end=' ')
    print()
# Out:
# * * * * *
# *
# * * * * *
#         *
# * * * * *

# %%
n = 5
for i in range(n):
    for j in range(n):
        if j==0 or (j==n-1 and i<n//2) or (i==j and i>n//2) or i==0 or i==n//2 :
            print('*',end=' ')
        else:
            print(' ',end=' ')
    print()
# Out:
# * * * * *
# *       *
# * * * * *
# *     *
# *       *

# %%
n = 5
for i in range(n):
    for j in range(n):
        if i==0 or i==n-1 or j==n//2:
            print('*',end=' ')
        else:
            print(' ',end=' ')
    print()
# Out:
# * * * * *
#     *
#     *
#     *
# * * * * *

# %%
n = 5
for i in range(n):
    for j in range(n):
        if i==0 or j==n//2:
            print('*',end=' ')
        else:
            print(' ',end=' ')
    print()
# Out:
# * * * * *
#     *
#     *
#     *
#     *

# %%
n = 5
for i in range(n):
    for j in range(n):
        if j==0 or j==n-1 or i==n//2:
            print('*',end=' ')
        else:
            print(' ',end=' ')
    print()
# Out:
# *       *
# *       *
# * * * * *
# *       *
# *       *

# %%
n = 5
for i in range(n):
    for j in range(n):
        if j==0 or j==n-1 or i==0 or i==n//2:
            print('*',end=' ')
        else:
            print(' ',end=' ')
    print()
# Out:
# * * * * *
# *       *
# * * * * *
# *       *
# *       *

# %%
n = 5
for i in range(n):
    for j in range(n):
        if (j==0 and j==n//2) or i==0 or i==n//2 or j==0 or i==n-1:
            print('*',end=' ')
        else:
            print(' ',end=' ')
    print()
# Out:
# * * * * *
# *
# * * * * *
# *
# * * * * *

# %%
n = 5
for i in range(n):
    for j in range(n):
        if (j==n-i and j==n//2) or (i ==j and i<n//2) or (n==i+j+1 and i<=n//2):
            print('*',end=' ')
        else:
            print(' ',end=' ')
    print()
# Out:
# *       *
#   *   *
#     *
#     *

# %%
n = 7
for i in range(n):
    for j in range(n):
        if j==0 or (i + j==n//2) or (i-j==n//2) :
            print('*',end=' ')
        else:
            print(' ',end=' ')
    print()
# Out:
# *     *
# *   *
# * *
# *
# * *
# *   *
# *     *
